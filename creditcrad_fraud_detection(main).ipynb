# %%
''' ok so this is a single model for credit card fraud detec.
here in this model i have used the random forest model for computing
'''
# =================================================================

# these are the imported lib.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
from sklearn.model_selection import train_test_split
# import Randomforestclassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# i have called the file from its path
df = pd.read_excel(r"C:\Users\shubh\OneDrive\Desktop\workspace\drive-download\CREDIT_CARD_FRAUD_hybrid_model\creditcard.xlsx")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 21873  31906  1.285161 -0.701455  0.221870 -0.744753 -0.674967  0.034267
# 21874  31906 -0.345979  1.094568  1.282208  0.068241 -0.016965 -0.989567
# 21875  31907  1.171852  0.718042 -0.227521  1.373722  0.152349 -0.949840
# 21876  31907  1.209330 -1.130242  1.614261  0.000265 -1.974416  0.262320
# 21877  31907 -0.184653  0.376693  0.632988 -2.282365  0.403553 -0.371666
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 21873 -0.631373  0.097860 -0.835749  ...  0.083025  0.190059 -0.074942
# 21874  0.693958 -0.050855 -0.333856  ... -0.266852 -0.723026 -0.003364
# 21875  0.271427 -0.153000 -0.184297  ... -0.013584  0.088759 -0.059148
# 21876 -1.369554  0.173769  0.639855  ... -0.520157 -0.573057  0.037646
# 21877  0.695359 -0.064835  0.610986  ... -0.130997 -0.312833 -0.156567
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# cleaning the dataset
df.isnull().sum()# this line of code tell how many null values are there in a colunm
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
# here we are removing the null values
df = df.dropna()
df.isnull().sum()

'''notes
the random forest classifier can be used for both classification and regression modeling
thus we have used it here well the special thing about the rfc model is that it doesnt require and kind of data cleaning
still i have clean the data becoz to show it doen in this way.
'''
# Out:
# 'notes\nthe random forest classifier can be used for both classification and regression modeling\nthus we have used it here well the special thing about the rfc model is that it doesnt require and kind of data cleaning\nstill i have clean the data becoz to show it doen in this way.\n'

# %%
df.shape
# Out:
# (21877, 31)

# %%
df.describe()#this line of code gives the basic details
# Out:
#                Time            V1            V2            V3            V4  \
# count  21877.000000  21877.000000  21877.000000  21877.000000  21877.000000
# mean   16923.586689     -0.241062      0.222117      0.737919      0.262269
# std    11005.194861      1.880944      1.518145      1.740987      1.451003
# min        0.000000    -30.552380    -40.978852    -31.103685     -5.172595
# 25%     5495.000000     -0.960944     -0.350080      0.297985     -0.648858
# 50%    18769.000000     -0.299324      0.206459      0.888766      0.222377
# 75%    27778.000000      1.164879      0.858520      1.520392      1.132696
# max    31907.000000      1.960497     16.713389      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  21877.000000  21877.000000  21877.000000  21877.000000  21877.000000
# mean      -0.175253      0.087517     -0.141050      0.019343      0.562077
# ...

# %%
sum(df['Class'])
# Out:
# 86.0

# %%
# getting the total of all the non-fraud entries in the dtaa
non_fraud = len(df[df.Class == 0])
print(non_fraud)
# Out:
# 21791

# %%
# getting the total fraud form the complete entries
fraud = len(df[df.Class == 1])
print(fraud)
# Out:
# 86

# %%
df["Amount"].var()
# Out:
# 42039.14640913151

# %%
# here we will be using RFM which dont require standardise the data
scaler  = StandardScaler()

# %%
df['Normailzed_amounnt'] = scaler.fit_transform(df['Amount'].values.reshape(-1,1))

# %%
df.drop(['Amount', 'Time'], axis = 1, inplace = True)

# %%
# making all the independent valrible
x = df.drop(["Class"], axis = 1)
y = df["Class"]

# %%
# making the trian and test data by dividing the data with the testsize of 0.3
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 1)

# %% [markdown]
# Appling the RandomForest method to Classify the Fraud or non Fraud

# %%
rf = RandomForestClassifier (n_estimators = 100)#giving the number of trees in the forest
rf.fit(x_train, y_train)#train our training data
pre_f = rf.predict(x_test)#doing the prediction
rf_froest = rf.score(x_test, y_test)*100
rf_froest#calcuating the accuracy
all = classification_report(y_test, pre_f)

# %%
print(all)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6537
#          1.0       1.00      0.78      0.88        27
#
#     accuracy                           1.00      6564
#    macro avg       1.00      0.89      0.94      6564
# weighted avg       1.00      1.00      1.00      6564

# %% [markdown]
# Appling Hybrid machine learning model, where we are using CNN and RandomForest to do the same.

# %%
# Create the CNN model
cnn_model = Sequential()
# cnn_model = Sequential()
cnn_model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(x_train.shape[1],1)))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Flatten())
cnn_model.add(Dense(128, activation='relu'))
cnn_model.add(Dense(1, activation='sigmoid'))
# Create the random forest model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model
# Out:
# WARNING:tensorflow:From c:\Users\shubh\OneDrive\Desktop\workspace\for_all\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\shubh\OneDrive\Desktop\workspace\for_all\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# RandomForestClassifier()

# %%
# !pip3 install ann_visualizer
from ann_visualizer.visualize import ann_viz;

# %%
# Train the CNN model
cnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
cnn_model.fit(x_train, y_train, epochs=10 )

# Extract the features from the CNN model
cnn_features = cnn_model.predict(x_test)
cnn_model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\shubh\OneDrive\Desktop\workspace\for_all\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\shubh\OneDrive\Desktop\workspace\for_all\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\shubh\OneDrive\Desktop\workspace\for_all\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 479/479 [==============================] - 2s 2ms/step - loss: 0.0324 - accuracy: 0.9969
# Epoch 2/10
# 479/479 [==============================] - 1s 2ms/step - loss: 0.0060 - accuracy: 0.9980
# Epoch 3/10
# ...

# %%
ann_viz(cnn_model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 ann_viz(cnn_model)
#
# File c:\Users\shubh\OneDrive\Desktop\workspace\for_all\Lib\site-packages\ann_visualizer\visualize.py:30, in ann_viz(model, view, filename, title)
#      18 def ann_viz(model, view=True, filename="network.gv", title="My Neural Network"):
#      19     """Vizualizez a Sequential model.
#      20
#      21     # Arguments
#    (...)
#      28         title: A title for the graph
#      29     """
# ---> 30     from graphviz import Digraph;
#      31     import keras;
#      32     from keras.models import Sequential;
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
# Train the random forest model on the CNN features
rf_model.fit(cnn_features, y_test)
# Out:
# RandomForestClassifier()

# %%
# Make predictions on the test set
y_pred = rf_model.predict(cnn_model.predict(x_test))
y_pred
# Out:
# 206/206 [==============================] - 0s 991us/step
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
accuracy = np.sum(y_pred == y_test) / len(y_test)#precision
print('Accuracy:', accuracy*100)
# Out:
# Accuracy: 99.96953077391835

# %%
a = classification_report(y_test, y_pred)
print(a)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6537
#          1.0       1.00      0.93      0.96        27
#
#     accuracy                           1.00      6564
#    macro avg       1.00      0.96      0.98      6564
# weighted avg       1.00      1.00      1.00      6564

# %%
from sklearn.metrics import precision_score, recall_score, fbeta_score, confusion_matrix, precision_recall_curve, accuracy_score

# %%
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[6537    0]
#  [   2   25]]
